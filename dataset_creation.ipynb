# %%
from datetime import date
import pandas as pd
import numpy as np
import copy
import sqlite3
conn = sqlite3.connect('data/database.sqlite')
pd.set_option('display.max_columns', 500)

# %% [markdown]
# # Create dataframe of relevant matches  with details about shot on target and goals. Only matches without red cards

# %%
# 10, 15, 20, 25
threshold_over_50 = 10
poss_name = 'possession_until_halftime'
Y_column = 'shots_on_second_half'
file_name = 'data/statistics_no_tie_matches_poss_first_half.csv'

# %%
df = pd.read_csv(file_name)
df = df[abs(df[poss_name] - 50) >= threshold_over_50]
# df = df.groupby("match_id").apply(pd.DataFrame.sample, n=1)

df['T'] = df[poss_name] >= (50+threshold_over_50)

df = df.drop(columns=["Unnamed: 0", 'shots_on', 'goals', 'goals_second_half', poss_name])
df = df.reset_index()
df.head()
# Out:
#    index  match_id  team_id  shots_on_first_half  shots_on_second_half  \
# 0      2      1730     9825                    7                     5
# 1      3      1730     8659                    0                     2
# 2     16      1738     8462                    5                     2
# 3     17      1738     8455                    5                     1
# 4     48      1757     9825                    3                     1
#
#    goals_first_half      T
# 0                 1   True
# 1                 0  False
# 2                 3  False
# 3                 0   True
# 4                 1   True

# %%
df_matches = pd.read_sql("""SELECT * FROM Match;""", conn)
# df_matches = pd.read_csv("match.csv")
df_matches = df_matches.drop(columns=['PSH','PSD','PSA','foulcommit','shotoff','shoton','goal','card','cross','corner','possession','home_team_goal','away_team_goal','match_api_id','home_player_X1','home_player_X2','home_player_X3','home_player_X4','home_player_X5',
                                      'home_player_X6','home_player_X7','home_player_X8','home_player_X9','home_player_X10','home_player_X11',
                                     'away_player_X1','away_player_X2','away_player_X3','away_player_X4','away_player_X5',
                                      'away_player_X6','away_player_X7','away_player_X8','away_player_X9','away_player_X10','away_player_X11',
                                     'home_player_Y1','home_player_Y2','home_player_Y3','home_player_Y4','home_player_Y5','home_player_Y6',
                                     'home_player_Y7','home_player_Y8','home_player_Y9','home_player_Y10','home_player_Y11',
                                     'away_player_Y1','away_player_Y2','away_player_Y3','away_player_Y4','away_player_Y5','away_player_Y6',
                                     'away_player_Y7','away_player_Y8','away_player_Y9','away_player_Y10','away_player_Y11'])
df = pd.merge(df, df_matches, left_on = 'match_id', right_on = 'id')

# %%
#exclude games with red cards #
df_cards = pd.read_csv('data/matches_with_red_card.csv')
print('before red:', len(df))
df = pd.merge(df,df_cards,how='outer', left_on = 'id', right_on = 'match_id', indicator = True)
df = df[df['_merge'] == 'left_only']
print('after red:', len(df))

df = df.drop(columns=['card_type', '_merge', 'Unnamed: 0'])

df['is_home_team'] = df.team_id == df.home_team_api_id

df.to_csv('check.csv')
# Out:
# before red: 3780
# after red: 2924

# %% [markdown]
# # Create team ratings dataset

# %%
# construct a dictionary of players' ratings for different timestamps

d = {}
df_players = pd.read_sql("""SELECT * FROM player_attributes;""", conn)
df_players['date'] = df_players['date'].astype('datetime64[ns]') 
ips = df_players.player_api_id.unique()
for ip in ips:
    df = df_players[df_players['player_api_id'] == ip]
    d[ip] = dict(zip(df.date,df.overall_rating))
#df_players
#date = df_players['date'].astype('date')
#d = dict(zip(df_players.player_api_id,df_players.overall_rating))
#   Timestamp('2010-08-30 00:00:00'): 79.0,
#   Timestamp('2009-08-30 00:00:00'): 80.0,
#   Timestamp('2009-02-22 00:00:00'): 80.0,
#   Timestamp('2008-08-30 00:00:00'): 84.0,
#   Timestamp('2007-08-30 00:00:00'): 82.0,
#   Timestamp('2007-02-22 00:00:00'): 82.0},
#  178702: {Timestamp('2014-09-18 00:00:00'): 60.0,
#   Timestamp('2014-01-10 00:00:00'): 60.0,
#   Timestamp('2013-09-20 00:00:00'): 60.0,
#   Timestamp('2012-02-22 00:00:00'): 60.0,
#   Timestamp('2011-08-30 00:00:00'): 60.0,
#   Timestamp('2009-02-22 00:00:00'): 60.0,
#   Timestamp('2007-02-22 00:00:00'): 60.0},
#  168727: {Timestamp('2016-05-12 00:00:00'): 74.0,
#   Timestamp('2016-05-05 00:00:00'): 74.0,
#   Timestamp('2016-04-21 00:00:00'): 74.0,
#   Timestamp('2016-04-14 00:00:00'): 74.0,
#   Timestamp('2016-03-17 00:00:00'): 73.0,
#   Timestamp('2015-09-21 00:00:00'): 73.0,
#   Timestamp('2015-04-17 00:00:00'): 69.0,
#   Timestamp('2015-04-10 00:00:00'): 69.0,
#   Timestamp('2014-12-12 00:00:00'): 67.0,
#   Timestamp('2014-10-31 00:00:00'): 66.0,
#   Timestamp('2014-10-10 00:00:00'): 65.0,
#   Timestamp('2014-09-18 00:00:00'): 63.0,
#   Timestamp('2014-04-11 00:00:00'): 64.0,
#   Timestamp('2014-02-28 00:00:00'): 62.0,
#   Timestamp('2014-01-31 00:00:00'): 55.0,
#   Timestamp('2014-01-03 00:00:00'): 54.0,
#   Timestamp('2013-12-27 00:00:00'): 54.0,
#   Timestamp('2013-11-08 00:00:00'): 59.0,
#   Timestamp('2013-09-20 00:00:00'): 57.0,
#   Timestamp('2010-02-22 00:00:00'): 57.0,
#   Timestamp('2009-08-30 00:00:00'): 53.0,
#   Timestamp('2007-02-22 00:00:00'): 53.0},
#  ...}

# %%
# construct a dictionary of team ratings

d_power = {}
df_check = pd.read_csv('data/check.csv')
seasons = df_check.season.unique()
#print(seasons[0])
teams = set().union(*[df_check.home_team_api_id.unique(),df_check.away_team_api_id.unique()])
print(len(teams))
#print(teams[0])
for team in list(teams):
    d_power[team] = {}
    #print(team)
    for s in seasons:
        d_power[team][s] = {'field':0, 'gk':0}
        power = 0
        num_players = 0
        gk_power = 0
        num_gk = 0
        year_1, year_2 = s.split('/')
        #print(team,s)
        df = df_check[(df_check.home_team_api_id == team) | (df_check.away_team_api_id == team)]
        df = df[df['season'] == s]
        for i, row in df.iterrows():
            home_or_away = 'home' if row.home_team_api_id == team else 'away'
            for c in [f'{home_or_away}_player_{i}' for i in range(1,12)]:
                #print(c)
                if pd.notna(row[c]):
                    dates = list(d[row[c]].keys())
                    time_to_compare = pd.Timestamp(f'{year_2}-01-01T12')
                    chosen_date = dates[np.argmin([abs(date - time_to_compare) for date in dates])]
                    #print([abs(date - time_to_compare) for date in dates])
                    #print(chosen_date)
                    if  c == f'{home_or_away}_player_1':
                        gk_power += d[row[c]][chosen_date]
                        num_gk +=1
                    else:
                        power += d[row[c]][chosen_date]
                        num_players+=1
        if num_players != 0: 
            d_power[team][s]['field'] = power/num_players
        else:
            d_power[team][s]['field'] = np.nan
        if num_gk != 0: 
            d_power[team][s]['gk'] = gk_power/num_gk
        else:
            d_power[team][s]['gk'] = np.nan
# Out:
# 164

# %%
#column_names = ["team_id", "2008/2009_overall", "2009/2010_overall","2010/2011_overall","2011/2012_overall","2012/2013_overall","2013/2014_overall","2014/2015_overall","2015/2016_overall",
#                "2008/2009_gk", "2009/2010_gk", "2010/2011_gk", "2011/2012_gk", "2012/2013_gk", "2013/2014_gk", "2014/2015_gk", "2015/2016_gk"]

column_names = ["team_id", "season", "field players rating", "gk rating"]
df_power_ratings = pd.DataFrame(columns = column_names)
i = 0 
for team in list(d_power.keys()):
    for season in list(d_power[team].keys()):
        df_power_ratings.loc[i] = [team] + [season] + [d_power[team][season]['field']] + [d_power[team][season]['gk']]
        i +=1

#df_power_ratings[df_power_ratings['2015/2016_gk'] > 87]

df_power_ratings.to_csv('teams_ratings.csv')

# %% [markdown]
# # Create team attributes dataset

# %%
# construct a dictionary of team attributes for different timestamps

d = {}
# df_teams = pd.read_csv("team_attributes.csv")
df_teams = pd.read_sql("""SELECT * FROM Team_Attributes;""", conn)
columns = list(df_teams.columns)
df_teams['date'] = df_teams['date'].astype('datetime64[ns]') 
ips = df_teams.team_api_id.unique()
for ip in ips:
    d[ip] = {}
    df = df_teams[df_teams['team_api_id'] == ip]
    for i,row in df.iterrows():
        d[ip][row['date']] = {}
        for c in columns:
            if c not in ['id','team_fifa_api_id', 'team_api_id', 'date']:
                d[ip][row['date']][c] = row[c]
#df_players
#date = df_players['date'].astype('date')
#d = dict(zip(df_players.player_api_id,df_players.overall_rating))
#date
d
# Out:
# {9930: {Timestamp('2010-02-22 00:00:00'): {'buildUpPlaySpeed': 60,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': nan,
#    'buildUpPlayDribblingClass': 'Little',
#    'buildUpPlayPassing': 50,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 60,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 65,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 55,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 50,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 55,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 45,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'},
#   Timestamp('2014-09-19 00:00:00'): {'buildUpPlaySpeed': 52,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': 48.0,
#    'buildUpPlayDribblingClass': 'Normal',
#    'buildUpPlayPassing': 56,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 54,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 63,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 64,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 47,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 44,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 54,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'},
#   Timestamp('2015-09-10 00:00:00'): {'buildUpPlaySpeed': 47,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': 41.0,
#    'buildUpPlayDribblingClass': 'Normal',
#    'buildUpPlayPassing': 54,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 54,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 63,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 64,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 47,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 44,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 54,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'}},
#  8485: {Timestamp('2010-02-22 00:00:00'): {'buildUpPlaySpeed': 70,
#    'buildUpPlaySpeedClass': 'Fast',
#    'buildUpPlayDribbling': nan,
#    'buildUpPlayDribblingClass': 'Little',
#    'buildUpPlayPassing': 70,
#    'buildUpPlayPassingClass': 'Long',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 70,
#    'chanceCreationPassingClass': 'Risky',
#    'chanceCreationCrossing': 70,
#    'chanceCreationCrossingClass': 'Lots',
#    'chanceCreationShooting': 70,
#    'chanceCreationShootingClass': 'Lots',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 60,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 70,
#    'defenceAggressionClass': 'Double',
#    'defenceTeamWidth': 70,
#    'defenceTeamWidthClass': 'Wide',
#    'defenceDefenderLineClass': 'Cover'},
#   Timestamp('2011-02-22 00:00:00'): {'buildUpPlaySpeed': 47,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': nan,
#    'buildUpPlayDribblingClass': 'Little',
#    'buildUpPlayPassing': 52,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 53,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 48,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 52,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 47,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 47,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 52,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'},
#   Timestamp('2012-02-22 00:00:00'): {'buildUpPlaySpeed': 58,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': nan,
#    'buildUpPlayDribblingClass': 'Little',
#    'buildUpPlayPassing': 62,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 45,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 70,
#    'chanceCreationCrossingClass': 'Lots',
#    'chanceCreationShooting': 55,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 40,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 40,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 60,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'},
#   Timestamp('2013-09-20 00:00:00'): {'buildUpPlaySpeed': 62,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': nan,
#    'buildUpPlayDribblingClass': 'Little',
#    'buildUpPlayPassing': 45,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 40,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 50,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 55,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 42,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 42,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 60,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'},
#   Timestamp('2014-09-19 00:00:00'): {'buildUpPlaySpeed': 58,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': 64.0,
#    'buildUpPlayDribblingClass': 'Normal',
#    'buildUpPlayPassing': 62,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 56,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 68,
#    'chanceCreationCrossingClass': 'Lots',
#    'chanceCreationShooting': 57,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 41,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 42,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 60,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'},
#   Timestamp('2015-09-10 00:00:00'): {'buildUpPlaySpeed': 59,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': 64.0,
#    'buildUpPlayDribblingClass': 'Normal',
#    'buildUpPlayPassing': 53,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 51,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 72,
#    'chanceCreationCrossingClass': 'Lots',
#    'chanceCreationShooting': 63,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Free Form',
#    'defencePressure': 49,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 45,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 63,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'}},
#  8576: {Timestamp('2010-02-22 00:00:00'): {'buildUpPlaySpeed': 60,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': nan,
#    'buildUpPlayDribblingClass': 'Little',
#    'buildUpPlayPassing': 40,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 45,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 35,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 55,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 30,
#    'defencePressureClass': 'Deep',
#    'defenceAggression': 70,
#    'defenceAggressionClass': 'Double',
#    'defenceTeamWidth': 30,
#    'defenceTeamWidthClass': 'Narrow',
#    'defenceDefenderLineClass': 'Offside Trap'},
#   Timestamp('2011-02-22 00:00:00'): {'buildUpPlaySpeed': 65,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': nan,
#    'buildUpPlayDribblingClass': 'Little',
#    'buildUpPlayPassing': 45,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 65,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 65,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 50,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 45,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 45,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 50,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'},
#   Timestamp('2012-02-22 00:00:00'): {'buildUpPlaySpeed': 59,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': nan,
#    'buildUpPlayDribblingClass': 'Little',
#    'buildUpPlayPassing': 52,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 48,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 34,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 52,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 38,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 47,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 53,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'},
#   Timestamp('2013-09-20 00:00:00'): {'buildUpPlaySpeed': 59,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': nan,
#    'buildUpPlayDribblingClass': 'Little',
#    'buildUpPlayPassing': 52,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 48,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 34,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 52,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 38,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 47,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 53,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'},
#   Timestamp('2014-09-19 00:00:00'): {'buildUpPlaySpeed': 59,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': 57.0,
#    'buildUpPlayDribblingClass': 'Normal',
#    'buildUpPlayPassing': 52,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 48,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 38,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 52,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 38,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 47,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 53,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'},
#   Timestamp('2015-09-10 00:00:00'): {'buildUpPlaySpeed': 59,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': 57.0,
#    'buildUpPlayDribblingClass': 'Normal',
#    'buildUpPlayPassing': 52,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 48,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 38,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 52,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 38,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 47,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 53,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'}},
#  8564: {Timestamp('2010-02-22 00:00:00'): {'buildUpPlaySpeed': 45,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': nan,
#    'buildUpPlayDribblingClass': 'Little',
#    'buildUpPlayPassing': 30,
#    'buildUpPlayPassingClass': 'Short',
#    'buildUpPlayPositioningClass': 'Free Form',
#    'chanceCreationPassing': 55,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 45,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 70,
#    'chanceCreationShootingClass': 'Lots',
#    'chanceCreationPositioningClass': 'Free Form',
#    'defencePressure': 30,
#    'defencePressureClass': 'Deep',
#    'defenceAggression': 35,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 60,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Offside Trap'},
#   Timestamp('2011-02-22 00:00:00'): {'buildUpPlaySpeed': 65,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': nan,
#    'buildUpPlayDribblingClass': 'Little',
#    'buildUpPlayPassing': 50,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 50,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 60,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 50,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Free Form',
#    'defencePressure': 50,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 50,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 50,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Offside Trap'},
#   Timestamp('2012-02-22 00:00:00'): {'buildUpPlaySpeed': 45,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': nan,
#    'buildUpPlayDribblingClass': 'Little',
#    'buildUpPlayPassing': 50,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 65,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 20,
#    'chanceCreationCrossingClass': 'Little',
#    'chanceCreationShooting': 50,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Free Form',
#    'defencePressure': 45,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 45,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 50,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'},
#   Timestamp('2013-09-20 00:00:00'): {'buildUpPlaySpeed': 48,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': nan,
#    'buildUpPlayDribblingClass': 'Little',
#    'buildUpPlayPassing': 54,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 51,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 53,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 64,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Free Form',
#    'defencePressure': 48,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 49,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 53,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'},
#   Timestamp('2014-09-19 00:00:00'): {'buildUpPlaySpeed': 48,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': 70.0,
#    'buildUpPlayDribblingClass': 'Lots',
#    'buildUpPlayPassing': 52,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 66,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 36,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 75,
#    'chanceCreationShootingClass': 'Lots',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 58,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 57,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 49,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'},
#   Timestamp('2015-09-10 00:00:00'): {'buildUpPlaySpeed': 48,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': 70.0,
#    'buildUpPlayDribblingClass': 'Lots',
#    'buildUpPlayPassing': 52,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 66,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 36,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 69,
#    'chanceCreationShootingClass': 'Lots',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 58,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 57,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 49,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'}},
#  10215: {Timestamp('2010-02-22 00:00:00'): {'buildUpPlaySpeed': 30,
#    'buildUpPlaySpeedClass': 'Slow',
#    'buildUpPlayDribbling': nan,
#    'buildUpPlayDribblingClass': 'Little',
#    'buildUpPlayPassing': 30,
#    'buildUpPlayPassingClass': 'Short',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 50,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 60,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 55,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 30,
#    'defencePressureClass': 'Deep',
#    'defenceAggression': 30,
#    'defenceAggressionClass': 'Contain',
#    'defenceTeamWidth': 30,
#    'defenceTeamWidthClass': 'Narrow',
#    'defenceDefenderLineClass': 'Offside Trap'},
#   Timestamp('2011-02-22 00:00:00'): {'buildUpPlaySpeed': 30,
#    'buildUpPlaySpeedClass': 'Slow',
#    'buildUpPlayDribbling': nan,
#    'buildUpPlayDribblingClass': 'Little',
#    'buildUpPlayPassing': 50,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 50,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 50,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 55,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 30,
#    'defencePressureClass': 'Deep',
#    'defenceAggression': 45,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 65,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'},
#   Timestamp('2012-02-22 00:00:00'): {'buildUpPlaySpeed': 45,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': nan,
#    'buildUpPlayDribblingClass': 'Little',
#    'buildUpPlayPassing': 44,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 55,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 57,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 60,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 52,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 38,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 61,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'},
#   Timestamp('2013-09-20 00:00:00'): {'buildUpPlaySpeed': 45,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': nan,
#    'buildUpPlayDribblingClass': 'Little',
#    'buildUpPlayPassing': 44,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 55,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 57,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 60,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 52,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 38,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 61,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'},
#   Timestamp('2014-09-19 00:00:00'): {'buildUpPlaySpeed': 52,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': 53.0,
#    'buildUpPlayDribblingClass': 'Normal',
#    'buildUpPlayPassing': 44,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 55,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 51,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 60,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 39,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 38,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 61,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'},
#   Timestamp('2015-09-10 00:00:00'): {'buildUpPlaySpeed': 53,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': 53.0,
#    'buildUpPlayDribblingClass': 'Normal',
#    'buildUpPlayPassing': 44,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 55,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 51,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 60,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 39,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 38,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 61,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'}},
#  10217: {Timestamp('2010-02-22 00:00:00'): {'buildUpPlaySpeed': 30,
#    'buildUpPlaySpeedClass': 'Slow',
#    'buildUpPlayDribbling': nan,
#    'buildUpPlayDribblingClass': 'Little',
#    'buildUpPlayPassing': 35,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 30,
#    'chanceCreationPassingClass': 'Safe',
#    'chanceCreationCrossing': 50,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 65,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 30,
#    'defencePressureClass': 'Deep',
#    'defenceAggression': 30,
#    'defenceAggressionClass': 'Contain',
#    'defenceTeamWidth': 30,
#    'defenceTeamWidthClass': 'Narrow',
#    'defenceDefenderLineClass': 'Cover'},
#   Timestamp('2011-02-22 00:00:00'): {'buildUpPlaySpeed': 53,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': nan,
#    'buildUpPlayDribblingClass': 'Little',
#    'buildUpPlayPassing': 53,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 48,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 67,
#    'chanceCreationCrossingClass': 'Lots',
#    'chanceCreationShooting': 66,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 46,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 62,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 65,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'},
#   Timestamp('2012-02-22 00:00:00'): {'buildUpPlaySpeed': 38,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': nan,
#    'buildUpPlayDribblingClass': 'Little',
#    'buildUpPlayPassing': 44,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 55,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 60,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 44,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 50,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 58,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 62,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'},
#   Timestamp('2013-09-20 00:00:00'): {'buildUpPlaySpeed': 38,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': nan,
#    'buildUpPlayDribblingClass': 'Little',
#    'buildUpPlayPassing': 47,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 55,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 55,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 44,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 50,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 58,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 52,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'},
#   Timestamp('2014-09-19 00:00:00'): {'buildUpPlaySpeed': 58,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': 47.0,
#    'buildUpPlayDribblingClass': 'Normal',
#    'buildUpPlayPassing': 55,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 55,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 52,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 44,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 57,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 50,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 52,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'},
#   Timestamp('2015-09-10 00:00:00'): {'buildUpPlaySpeed': 56,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': 40.0,
#    'buildUpPlayDribblingClass': 'Normal',
#    'buildUpPlayPassing': 66,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 55,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 52,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 38,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 40,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 50,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 52,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'}},
#  8593: {Timestamp('2010-02-22 00:00:00'): {'buildUpPlaySpeed': 30,
#    'buildUpPlaySpeedClass': 'Slow',
#    'buildUpPlayDribbling': nan,
#    'buildUpPlayDribblingClass': 'Little',
#    'buildUpPlayPassing': 30,
#    'buildUpPlayPassingClass': 'Short',
#    'buildUpPlayPositioningClass': 'Free Form',
#    'chanceCreationPassing': 50,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 60,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 70,
#    'chanceCreationShootingClass': 'Lots',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 30,
#    'defencePressureClass': 'Deep',
#    'defenceAggression': 30,
#    'defenceAggressionClass': 'Contain',
#    'defenceTeamWidth': 30,
#    'defenceTeamWidthClass': 'Narrow',
#    'defenceDefenderLineClass': 'Cover'},
#   Timestamp('2011-02-22 00:00:00'): {'buildUpPlaySpeed': 40,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': nan,
#    'buildUpPlayDribblingClass': 'Little',
#    'buildUpPlayPassing': 38,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Free Form',
#    'chanceCreationPassing': 67,
#    'chanceCreationPassingClass': 'Risky',
#    'chanceCreationCrossing': 65,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 67,
#    'chanceCreationShootingClass': 'Lots',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 65,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 57,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 63,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'},
#   Timestamp('2012-02-22 00:00:00'): {'buildUpPlaySpeed': 31,
#    'buildUpPlaySpeedClass': 'Slow',
#    'buildUpPlayDribbling': nan,
#    'buildUpPlayDribblingClass': 'Little',
#    'buildUpPlayPassing': 33,
#    'buildUpPlayPassingClass': 'Short',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 39,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 64,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 46,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Free Form',
#    'defencePressure': 68,
#    'defencePressureClass': 'High',
#    'defenceAggression': 65,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 60,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'},
#   Timestamp('2013-09-20 00:00:00'): {'buildUpPlaySpeed': 35,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': nan,
#    'buildUpPlayDribblingClass': 'Little',
#    'buildUpPlayPassing': 33,
#    'buildUpPlayPassingClass': 'Short',
#    'buildUpPlayPositioningClass': 'Free Form',
#    'chanceCreationPassing': 39,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 52,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 46,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Free Form',
#    'defencePressure': 68,
#    'defencePressureClass': 'High',
#    'defenceAggression': 65,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 50,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'},
#   Timestamp('2014-09-19 00:00:00'): {'buildUpPlaySpeed': 40,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': 40.0,
#    'buildUpPlayDribblingClass': 'Normal',
#    'buildUpPlayPassing': 30,
#    'buildUpPlayPassingClass': 'Short',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 51,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 55,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 39,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Free Form',
#    'defencePressure': 64,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 53,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 64,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'},
#   Timestamp('2015-09-10 00:00:00'): {'buildUpPlaySpeed': 35,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': 43.0,
#    'buildUpPlayDribblingClass': 'Normal',
#    'buildUpPlayPassing': 39,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 58,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 55,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 30,
#    'chanceCreationShootingClass': 'Little',
#    'chanceCreationPositioningClass': 'Free Form',
#    'defencePressure': 64,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 53,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 59,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'}},
#  9865: {Timestamp('2010-02-22 00:00:00'): {'buildUpPlaySpeed': 65,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': nan,
#    'buildUpPlayDribblingClass': 'Little',
#    'buildUpPlayPassing': 45,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 45,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 45,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 70,
#    'chanceCreationShootingClass': 'Lots',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 70,
#    'defencePressureClass': 'High',
#    'defenceAggression': 65,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 30,
#    'defenceTeamWidthClass': 'Narrow',
#    'defenceDefenderLineClass': 'Cover'},
#   Timestamp('2011-02-22 00:00:00'): {'buildUpPlaySpeed': 55,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': nan,
#    'buildUpPlayDribblingClass': 'Little',
#    'buildUpPlayPassing': 53,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 57,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 54,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 69,
#    'chanceCreationShootingClass': 'Lots',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 58,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 68,
#    'defenceAggressionClass': 'Double',
#    'defenceTeamWidth': 67,
#    'defenceTeamWidthClass': 'Wide',
#    'defenceDefenderLineClass': 'Cover'},
#   Timestamp('2012-02-22 00:00:00'): {'buildUpPlaySpeed': 42,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': nan,
#    'buildUpPlayDribblingClass': 'Little',
#    'buildUpPlayPassing': 70,
#    'buildUpPlayPassingClass': 'Long',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 57,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 54,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 40,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 37,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 53,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 45,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'},
#   Timestamp('2013-09-20 00:00:00'): {'buildUpPlaySpeed': 46,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': nan,
#    'buildUpPlayDribblingClass': 'Little',
#    'buildUpPlayPassing': 65,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 57,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 54,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 40,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 37,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 53,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 45,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'},
#   Timestamp('2014-09-19 00:00:00'): {'buildUpPlaySpeed': 46,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': 41.0,
#    'buildUpPlayDribblingClass': 'Normal',
#    'buildUpPlayPassing': 65,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 57,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 54,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 40,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 37,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 53,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 45,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'},
#   Timestamp('2015-09-10 00:00:00'): {'buildUpPlaySpeed': 46,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': 41.0,
#    'buildUpPlayDribblingClass': 'Normal',
#    'buildUpPlayPassing': 65,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 57,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 54,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 40,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 37,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 53,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 45,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'}},
#  8635: {Timestamp('2010-02-22 00:00:00'): {'buildUpPlaySpeed': 50,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': nan,
#    'buildUpPlayDribblingClass': 'Little',
#    'buildUpPlayPassing': 35,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 70,
#    'chanceCreationPassingClass': 'Risky',
#    'chanceCreationCrossing': 50,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 60,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 70,
#    'defencePressureClass': 'High',
#    'defenceAggression': 50,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 70,
#    'defenceTeamWidthClass': 'Wide',
#    'defenceDefenderLineClass': 'Cover'},
#   Timestamp('2011-02-22 00:00:00'): {'buildUpPlaySpeed': 50,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': nan,
#    'buildUpPlayDribblingClass': 'Little',
#    'buildUpPlayPassing': 52,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Free Form',
#    'chanceCreationPassing': 70,
#    'chanceCreationPassingClass': 'Risky',
#    'chanceCreationCrossing': 50,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 60,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 70,
#    'defencePressureClass': 'High',
#    'defenceAggression': 50,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 70,
#    'defenceTeamWidthClass': 'Wide',
#    'defenceDefenderLineClass': 'Offside Trap'},
#   Timestamp('2012-02-22 00:00:00'): {'buildUpPlaySpeed': 52,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': nan,
#    'buildUpPlayDribblingClass': 'Little',
#    'buildUpPlayPassing': 41,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 53,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 57,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 47,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 45,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 43,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 52,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'},
#   Timestamp('2013-09-20 00:00:00'): {'buildUpPlaySpeed': 52,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': nan,
#    'buildUpPlayDribblingClass': 'Little',
#    'buildUpPlayPassing': 41,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 68,
#    'chanceCreationPassingClass': 'Risky',
#    'chanceCreationCrossing': 67,
#    'chanceCreationCrossingClass': 'Lots',
#    'chanceCreationShooting': 47,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 60,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 43,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 65,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'},
#   Timestamp('2014-09-19 00:00:00'): {'buildUpPlaySpeed': 52,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': 46.0,
#    'buildUpPlayDribblingClass': 'Normal',
#    'buildUpPlayPassing': 51,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 60,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 53,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 47,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 60,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 50,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 65,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'},
#   Timestamp('2015-09-10 00:00:00'): {'buildUpPlaySpeed': 52,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': 46.0,
#    'buildUpPlayDribblingClass': 'Normal',
#    'buildUpPlayPassing': 51,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 60,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 53,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 47,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 53,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 50,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 61,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'}},
#  8121: {Timestamp('2010-02-22 00:00:00'): {'buildUpPlaySpeed': 45,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': nan,
#    'buildUpPlayDribblingClass': 'Little',
#    'buildUpPlayPassing': 35,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 35,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 50,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 60,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 30,
#    'defencePressureClass': 'Deep',
#    'defenceAggression': 55,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 30,
#    'defenceTeamWidthClass': 'Narrow',
#    'defenceDefenderLineClass': 'Offside Trap'},
#   Timestamp('2011-02-22 00:00:00'): {'buildUpPlaySpeed': 65,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': nan,
#    'buildUpPlayDribblingClass': 'Little',
#    'buildUpPlayPassing': 50,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 50,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 65,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 65,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 45,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 45,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 50,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'},
#   Timestamp('2012-02-22 00:00:00'): {'buildUpPlaySpeed': 50,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': nan,
#    'buildUpPlayDribblingClass': 'Little',
#    'buildUpPlayPassing': 50,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 52,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 52,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 48,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 44,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 44,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 51,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'},
#   Timestamp('2013-09-20 00:00:00'): {'buildUpPlaySpeed': 50,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': nan,
#    'buildUpPlayDribblingClass': 'Little',
#    'buildUpPlayPassing': 50,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 52,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 52,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 48,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 44,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 44,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 51,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'},
#   Timestamp('2014-09-19 00:00:00'): {'buildUpPlaySpeed': 48,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': 61.0,
#    'buildUpPlayDribblingClass': 'Normal',
#    'buildUpPlayPassing': 50,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 40,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 52,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 48,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 44,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 44,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 51,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'},
#   Timestamp('2015-09-10 00:00:00'): {'buildUpPlaySpeed': 48,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': 61.0,
#    'buildUpPlayDribblingClass': 'Normal',
#    'buildUpPlayPassing': 50,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 40,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 52,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 48,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 44,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 44,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 51,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'}},
#  8322: {Timestamp('2010-02-22 00:00:00'): {'buildUpPlaySpeed': 30,
#    'buildUpPlaySpeedClass': 'Slow',
#    'buildUpPlayDribbling': nan,
#    'buildUpPlayDribblingClass': 'Little',
#    'buildUpPlayPassing': 45,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 45,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 35,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 70,
#    'chanceCreationShootingClass': 'Lots',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 65,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 70,
#    'defenceAggressionClass': 'Double',
#    'defenceTeamWidth': 70,
#    'defenceTeamWidthClass': 'Wide',
#    'defenceDefenderLineClass': 'Cover'},
#   Timestamp('2011-02-22 00:00:00'): {'buildUpPlaySpeed': 46,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': nan,
#    'buildUpPlayDribblingClass': 'Little',
#    'buildUpPlayPassing': 37,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 33,
#    'chanceCreationPassingClass': 'Safe',
#    'chanceCreationCrossing': 62,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 52,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 47,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 48,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 45,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'}},
#  108893: {Timestamp('2010-02-22 00:00:00'): {'buildUpPlaySpeed': 50,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': nan,
#    'buildUpPlayDribblingClass': 'Little',
#    'buildUpPlayPassing': 65,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 30,
#    'chanceCreationPassingClass': 'Safe',
#    'chanceCreationCrossing': 35,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 30,
# ...
#    'buildUpPlayDribbling': 56.0,
#    'buildUpPlayDribblingClass': 'Normal',
#    'buildUpPlayPassing': 64,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 39,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 66,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 46,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 44,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 34,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 50,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'}},
#  8021: {Timestamp('2010-02-22 00:00:00'): {'buildUpPlaySpeed': 55,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': nan,
#    'buildUpPlayDribblingClass': 'Little',
#    'buildUpPlayPassing': 60,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 30,
#    'chanceCreationPassingClass': 'Safe',
#    'chanceCreationCrossing': 40,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 70,
#    'chanceCreationShootingClass': 'Lots',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 70,
#    'defencePressureClass': 'High',
#    'defenceAggression': 70,
#    'defenceAggressionClass': 'Double',
#    'defenceTeamWidth': 70,
#    'defenceTeamWidthClass': 'Wide',
#    'defenceDefenderLineClass': 'Cover'},
#   Timestamp('2011-02-22 00:00:00'): {'buildUpPlaySpeed': 54,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': nan,
#    'buildUpPlayDribblingClass': 'Little',
#    'buildUpPlayPassing': 37,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 48,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 38,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 37,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 47,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 58,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 52,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'},
#   Timestamp('2012-02-22 00:00:00'): {'buildUpPlaySpeed': 33,
#    'buildUpPlaySpeedClass': 'Slow',
#    'buildUpPlayDribbling': nan,
#    'buildUpPlayDribblingClass': 'Little',
#    'buildUpPlayPassing': 38,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 67,
#    'chanceCreationPassingClass': 'Risky',
#    'chanceCreationCrossing': 52,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 73,
#    'chanceCreationShootingClass': 'Lots',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 58,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 47,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 52,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'},
#   Timestamp('2013-09-20 00:00:00'): {'buildUpPlaySpeed': 33,
#    'buildUpPlaySpeedClass': 'Slow',
#    'buildUpPlayDribbling': nan,
#    'buildUpPlayDribblingClass': 'Little',
#    'buildUpPlayPassing': 38,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 67,
#    'chanceCreationPassingClass': 'Risky',
#    'chanceCreationCrossing': 52,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 48,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 58,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 47,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 52,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'},
#   Timestamp('2014-09-19 00:00:00'): {'buildUpPlaySpeed': 33,
#    'buildUpPlaySpeedClass': 'Slow',
#    'buildUpPlayDribbling': 49.0,
#    'buildUpPlayDribblingClass': 'Normal',
#    'buildUpPlayPassing': 51,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 38,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 63,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 48,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 58,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 38,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 52,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'}},
#  8394: {Timestamp('2010-02-22 00:00:00'): {'buildUpPlaySpeed': 30,
#    'buildUpPlaySpeedClass': 'Slow',
#    'buildUpPlayDribbling': nan,
#    'buildUpPlayDribblingClass': 'Little',
#    'buildUpPlayPassing': 30,
#    'buildUpPlayPassingClass': 'Short',
#    'buildUpPlayPositioningClass': 'Free Form',
#    'chanceCreationPassing': 50,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 35,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 70,
#    'chanceCreationShootingClass': 'Lots',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 40,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 30,
#    'defenceAggressionClass': 'Contain',
#    'defenceTeamWidth': 45,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Offside Trap'},
#   Timestamp('2011-02-22 00:00:00'): {'buildUpPlaySpeed': 43,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': nan,
#    'buildUpPlayDribblingClass': 'Little',
#    'buildUpPlayPassing': 40,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 46,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 38,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 42,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 38,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 40,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 53,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'},
#   Timestamp('2012-02-22 00:00:00'): {'buildUpPlaySpeed': 34,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': nan,
#    'buildUpPlayDribblingClass': 'Little',
#    'buildUpPlayPassing': 23,
#    'buildUpPlayPassingClass': 'Short',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 53,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 56,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 57,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 51,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 46,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 61,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'},
#   Timestamp('2013-09-20 00:00:00'): {'buildUpPlaySpeed': 38,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': nan,
#    'buildUpPlayDribblingClass': 'Little',
#    'buildUpPlayPassing': 23,
#    'buildUpPlayPassingClass': 'Short',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 53,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 56,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 57,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 51,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 46,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 61,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'},
#   Timestamp('2014-09-19 00:00:00'): {'buildUpPlaySpeed': 38,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': 48.0,
#    'buildUpPlayDribblingClass': 'Normal',
#    'buildUpPlayPassing': 35,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 53,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 56,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 57,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 51,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 46,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 61,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'},
#   Timestamp('2015-09-10 00:00:00'): {'buildUpPlaySpeed': 52,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': 52.0,
#    'buildUpPlayDribblingClass': 'Normal',
#    'buildUpPlayPassing': 50,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 52,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 56,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 57,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 48,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 43,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 49,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'}},
#  8027: {Timestamp('2014-09-19 00:00:00'): {'buildUpPlaySpeed': 54,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': 51.0,
#    'buildUpPlayDribblingClass': 'Normal',
#    'buildUpPlayPassing': 40,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 67,
#    'chanceCreationPassingClass': 'Risky',
#    'chanceCreationCrossing': 49,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 52,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 44,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 47,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 52,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'},
#   Timestamp('2015-09-10 00:00:00'): {'buildUpPlaySpeed': 54,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': 51.0,
#    'buildUpPlayDribblingClass': 'Normal',
#    'buildUpPlayPassing': 40,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 46,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 49,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 52,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 44,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 47,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 52,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'}},
#  10000: {Timestamp('2010-02-22 00:00:00'): {'buildUpPlaySpeed': 65,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': nan,
#    'buildUpPlayDribblingClass': 'Little',
#    'buildUpPlayPassing': 60,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 60,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 40,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 50,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 70,
#    'defencePressureClass': 'High',
#    'defenceAggression': 60,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 70,
#    'defenceTeamWidthClass': 'Wide',
#    'defenceDefenderLineClass': 'Cover'},
#   Timestamp('2011-02-22 00:00:00'): {'buildUpPlaySpeed': 52,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': nan,
#    'buildUpPlayDribblingClass': 'Little',
#    'buildUpPlayPassing': 52,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 52,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 48,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 53,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 46,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 48,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 53,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'},
#   Timestamp('2012-02-22 00:00:00'): {'buildUpPlaySpeed': 54,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': nan,
#    'buildUpPlayDribblingClass': 'Little',
#    'buildUpPlayPassing': 51,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 47,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 52,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 50,
#    'chanceCreationShootingClass': 'Normal',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 44,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 55,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 53,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'},
#   Timestamp('2013-09-20 00:00:00'): {'buildUpPlaySpeed': 54,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': nan,
#    'buildUpPlayDribblingClass': 'Little',
#    'buildUpPlayPassing': 51,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 47,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 52,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 32,
#    'chanceCreationShootingClass': 'Little',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 44,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 58,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 37,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'},
#   Timestamp('2014-09-19 00:00:00'): {'buildUpPlaySpeed': 54,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': 42.0,
#    'buildUpPlayDribblingClass': 'Normal',
#    'buildUpPlayPassing': 51,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 47,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 52,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 32,
#    'chanceCreationShootingClass': 'Little',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 44,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 58,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 37,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'},
#   Timestamp('2015-09-10 00:00:00'): {'buildUpPlaySpeed': 54,
#    'buildUpPlaySpeedClass': 'Balanced',
#    'buildUpPlayDribbling': 42.0,
#    'buildUpPlayDribblingClass': 'Normal',
#    'buildUpPlayPassing': 51,
#    'buildUpPlayPassingClass': 'Mixed',
#    'buildUpPlayPositioningClass': 'Organised',
#    'chanceCreationPassing': 47,
#    'chanceCreationPassingClass': 'Normal',
#    'chanceCreationCrossing': 52,
#    'chanceCreationCrossingClass': 'Normal',
#    'chanceCreationShooting': 32,
#    'chanceCreationShootingClass': 'Little',
#    'chanceCreationPositioningClass': 'Organised',
#    'defencePressure': 44,
#    'defencePressureClass': 'Medium',
#    'defenceAggression': 58,
#    'defenceAggressionClass': 'Press',
#    'defenceTeamWidth': 37,
#    'defenceTeamWidthClass': 'Normal',
#    'defenceDefenderLineClass': 'Cover'}}}

# %%
# construct a dictionary of team ratings

d_attributes = {}
df_check = pd.read_csv('data/check.csv')
seasons = df_check.season.unique()
#print(seasons[0])
teams = set().union(*[df_check.home_team_api_id.unique(),df_check.away_team_api_id.unique()])
print(len(teams))
#print(teams[0])
for team in list(teams):
    d_attributes[team] = {}
    #print(team)
    for s in seasons:
        d_power[team][s] = {}
        year_1, year_2 = s.split('/')
        time_to_compare = pd.Timestamp(f'{year_2}-01-01T12')
        dates = list(d[team].keys())
        chosen_date = dates[np.argmin([abs(date - time_to_compare) for date in dates])]
        d_attributes[team][s] = d[team][chosen_date]
# Out:
# 164

# %%
column_names = [
 'team_id',
 'season',
 'buildUpPlaySpeed',
 'buildUpPlaySpeedClass',
 'buildUpPlayDribbling',
 'buildUpPlayDribblingClass',
 'buildUpPlayPassing',
 'buildUpPlayPassingClass',
 'buildUpPlayPositioningClass',
 'chanceCreationPassing',
 'chanceCreationPassingClass',
 'chanceCreationCrossing',
 'chanceCreationCrossingClass',
 'chanceCreationShooting',
 'chanceCreationShootingClass',
 'chanceCreationPositioningClass',
 'defencePressure',
 'defencePressureClass',
 'defenceAggression',
 'defenceAggressionClass',
 'defenceTeamWidth',
 'defenceTeamWidthClass',
 'defenceDefenderLineClass']
df_team_attributes = pd.DataFrame(columns = column_names)
i = 0 
for team in list(d_attributes.keys()):
    for season in list(d_attributes[team].keys()):
        df_team_attributes.loc[i] = [team] + [season] + list(d_attributes[team][season].values())
        i +=1


#df_team_attributes.to_csv('teams_details.csv')

# %% [markdown]
# # Merge team ratings and attributes datasets and create one dataset from them

# %%
df_merge = pd.merge(df_team_attributes,df_power_ratings, right_on = ['team_id','season'], left_on = ['team_id','season'])


df_merge = df_merge.dropna(axis='rows', subset = ['gk rating'])

df_team_name = pd.read_sql("""SELECT * FROM team;""", conn)
# df_team_name = pd.read_csv('team.csv')
df_team_name = df_team_name.drop(columns=['team_short_name', 'team_fifa_api_id', 'id'])
df_merge = pd.merge(df_team_name,df_merge, right_on = ['team_id'], left_on = ['team_api_id'])
df_merge = df_merge.drop(columns = ['team_api_id', 'buildUpPlayDribbling'])
df_merge.to_csv('data/team_full_details.csv')
#df_merge.isna().sum()

# %% [markdown]
# # Merge the team ratings and attributes dataset with the mathces dataset
# # This is the main dataset for our analysis

# %%
# add df_merge to the relevant matches dataset:
new_columns = ['buildUpPlaySpeed', 'buildUpPlaySpeedClass', 'buildUpPlayDribblingClass', 
               'buildUpPlayPassing', 'buildUpPlayPassingClass', 'buildUpPlayPositioningClass', 
               'chanceCreationPassing', 'chanceCreationPassingClass', 'chanceCreationCrossing', 
               'chanceCreationCrossingClass', 'chanceCreationShooting', 'chanceCreationShootingClass', 
               'chanceCreationPositioningClass', 'defencePressure', 'defencePressureClass', 
               'defenceAggression', 'defenceAggressionClass', 'defenceTeamWidth', 'defenceTeamWidthClass', 
               'defenceDefenderLineClass', 'field players rating', 'gk rating']

df_check = pd.read_csv("data/check.csv")
df_teams_matches = pd.merge(df_check, df_merge, right_on=['team_id','season'], left_on=['home_team_api_id','season'])

for c in new_columns:
    df_teams_matches['curr_{}'.format(c)] = ""
    df_teams_matches['rival_{}'.format(c)] = ""

    df_teams_matches['dominating_{}'.format(c)] = ""
    df_teams_matches['dominated_{}'.format(c)] = ""

# print(df_teams_matches.columns)

for i, row in df_teams_matches.iterrows():
    if row['T'] == True:
        # T  -  not T
        if row['team_id_x'] == row['team_id_y']:
            for c in new_columns:
                df_teams_matches.loc[i, 'dominating_{}'.format(c)] = row[c]
        else:
            for c in new_columns:
                df_teams_matches.loc[i, 'dominated_{}'.format(c)] = row[c]
    else:
        if row['team_id_x'] == row['team_id_y']:
            for c in new_columns:
                df_teams_matches.loc[i, 'dominated_{}'.format(c)] = row[c]
        else:
            for c in new_columns:
                df_teams_matches.loc[i, 'dominating_{}'.format(c)] = row[c]
        
df_teams_matches = df_teams_matches.drop(columns = new_columns)


df_teams_matches = pd.merge(df_teams_matches,df_merge,right_on = ['team_id','season'], left_on = ['away_team_api_id','season'])

for i, row in df_teams_matches.iterrows():
    if row['T'] == True:
        if row['team_id_x'] == row['team_id']:
            for c in new_columns:
                df_teams_matches.loc[i, 'dominating_{}'.format(c)] = row[c]
        else:
            for c in new_columns:
                df_teams_matches.loc[i, 'dominated_{}'.format(c)] = row[c]
    else:
        if row['team_id_x'] == row['team_id']:
            for c in new_columns:
                df_teams_matches.loc[i, 'dominated_{}'.format(c)] = row[c]
        else:
            for c in new_columns:
                df_teams_matches.loc[i, 'dominating_{}'.format(c)] = row[c]
        
df_teams_matches = df_teams_matches.drop(columns = new_columns)

####TODO: remove useless columns and rename some columns before saving dataframe ####

df_teams_matches.to_csv("data/Mathces_with_full_team_details.csv")

# %%
try:
    df_teams_matches = df_teams_matches.drop('team_id', axis='columns', errors='ignore')
    df_teams_matches = df_teams_matches.rename({'match_id_x': 'match_id', 'team_id_x': 'team_id', 'team_long_name': 'team_name'}, axis='columns')
except Exception as e:
    print('exception7', e)

try:
    bets_cols = ['B365', 'BW', 'IW', 'LB', 'WH', 'SJ', 'VC', 'GB', 'BS']

    df_teams_matches['draw_bets'] = df_teams_matches[[b+'D' for b in bets_cols]].mean(axis='columns')

    home_mask = df_teams_matches['is_home_team']
    df_teams_matches.loc[home_mask, 'curr_bets'] = df_teams_matches.loc[home_mask, [b+'H' for b in bets_cols]].mean(axis='columns')
    df_teams_matches.loc[home_mask, 'rival_bets'] = df_teams_matches.loc[home_mask, [b+'A' for b in bets_cols]].mean(axis='columns')
    df_teams_matches.loc[~home_mask, 'curr_bets'] = df_teams_matches.loc[~home_mask, [b+'A' for b in bets_cols]].mean(axis='columns')
    df_teams_matches.loc[~home_mask, 'rival_bets'] = df_teams_matches.loc[~home_mask, [b+'H' for b in bets_cols]].mean(axis='columns')

except Exception as e:
    print('exception1', e)
try:
    for c in ['_team_api_id']:
        df_teams_matches.loc[home_mask, 'curr'+c] = df_teams_matches['home'+c]
        df_teams_matches.loc[home_mask, 'rival'+c] = df_teams_matches['away'+c]
        df_teams_matches.loc[~home_mask, 'curr'+c] = df_teams_matches['away'+c]
        df_teams_matches.loc[~home_mask, 'rival'+c] = df_teams_matches['home'+c]

except Exception as e:
    print('exception2', e)
    
try:
    dominating_mask = df_teams_matches['T']
    for c in new_columns:
        df_teams_matches.loc[dominating_mask, 'curr_'+c] = df_teams_matches['dominating_'+c]
        df_teams_matches.loc[dominating_mask, 'rival_'+c] = df_teams_matches['dominated_'+c]
        df_teams_matches.loc[~dominating_mask, 'curr_'+c] = df_teams_matches['dominated_'+c]
        df_teams_matches.loc[~dominating_mask, 'rival_'+c] = df_teams_matches['dominating_'+c]
    
except Exception as e:
    print('exception3', e)
    
try:
    df_teams_matches['curr_shots_1'] = df_teams_matches['shots_on_first_half']
    df_teams_matches['rival_shots_1'] = df_teams_matches.apply(lambda r: df_teams_matches[(df_teams_matches['match_id']==r['match_id']) & 
                                                                                          (df_teams_matches['curr_team_api_id']!=r['curr_team_api_id'])]
                                                           ['curr_shots_1'].iloc[0], axis='columns')
    
except Exception as e:
    print('exception4', e)


# try:
df_teams_matches['date'] = pd.to_datetime(df_teams_matches['date'])
df_teams_matches['month'] = df_teams_matches['date'].dt.month

teams = pd.read_sql("""SELECT * FROM Team;""", conn)
df_teams_matches = df_teams_matches.merge(teams[['team_api_id', 'team_long_name']], left_on='team_id', right_on='team_api_id').drop('team_api_id', axis='columns', errors='ignore')

country = pd.read_sql("""SELECT * FROM Country;""", conn)
df_teams_matches = df_teams_matches.merge(country.rename({'name': 'country_name'}, axis='columns'), left_on='country_id', right_on='id').drop('id', axis='columns', errors='ignore')

card = pd.read_csv('data/card_detail.csv')
match_cards = card[card['elapsed']<=45].groupby('match_id', as_index=False).size().rename({'size': 'cards'}, axis='columns')
print(df_teams_matches.columns, match_cards.columns)
df_teams_matches = df_teams_matches.merge(match_cards, on='match_id')

foul = pd.read_csv('data/foulcommit_detail.csv')
match_fouls = foul.groupby('match_id', as_index=False).size().rename({'size': 'fouls'}, axis='columns')
df_teams_matches = df_teams_matches.merge(match_fouls, on='match_id')    



remove_cols = ['home_player_1', 'home_player_2', 'home_player_3', 'home_player_4', 'home_player_5', 
               'home_player_6', 'home_player_7', 'home_player_8', 'home_player_9', 'home_player_10', 'home_player_11', 
               'away_player_1', 'away_player_2', 'away_player_3', 'away_player_4', 'away_player_5', 
               'away_player_6', 'away_player_7', 'away_player_8', 'away_player_9', 'away_player_10', 'away_player_11', 
               'B365H', 'B365D', 'B365A', 'BWH', 'BWD', 'BWA', 'IWH', 'IWD', 'IWA', 'LBH', 'LBD', 'LBA', 
               'WHH', 'WHD', 'WHA', 'SJH', 'SJD', 'SJA', 'VCH', 'VCD', 'VCA', 'GBH', 'GBD', 'GBA', 'BSH', 'BSD', 'BSA', 
               'dominating_buildUpPlaySpeed', 'dominated_buildUpPlaySpeed', 'dominating_buildUpPlaySpeedClass', 'dominated_buildUpPlaySpeedClass', 
               'dominating_buildUpPlayDribblingClass', 'dominated_buildUpPlayDribblingClass', 'dominating_buildUpPlayPassing', 'dominated_buildUpPlayPassing', 
               'dominating_buildUpPlayPassingClass', 'dominated_buildUpPlayPassingClass', 'dominating_buildUpPlayPositioningClass', 'dominated_buildUpPlayPositioningClass', 
               'dominating_chanceCreationPassing', 'dominated_chanceCreationPassing', 'dominating_chanceCreationPassingClass', 'dominated_chanceCreationPassingClass', 
               'dominating_chanceCreationCrossing', 'dominated_chanceCreationCrossing', 'dominating_chanceCreationCrossingClass', 'dominated_chanceCreationCrossingClass', 
               'dominating_chanceCreationShooting', 'dominated_chanceCreationShooting', 'dominating_chanceCreationShootingClass', 'dominated_chanceCreationShootingClass', 
               'dominating_chanceCreationPositioningClass', 'dominated_chanceCreationPositioningClass', 'dominating_defencePressure', 'dominated_defencePressure', 
               'dominating_defencePressureClass', 'dominated_defencePressureClass', 'dominating_defenceAggression', 'dominated_defenceAggression', 
               'dominating_defenceAggressionClass', 'dominated_defenceAggressionClass', 'dominating_defenceTeamWidth', 'dominated_defenceTeamWidth', 
               'dominating_defenceTeamWidthClass', 'dominated_defenceTeamWidthClass', 'dominating_defenceDefenderLineClass', 'dominated_defenceDefenderLineClass', 
               'dominating_field players rating', 'dominated_field players rating', 'dominating_gk rating', 'dominated_gk rating',
               'Unnamed: 0', 'index','away_team_api_id', 'home_team_api_id', 'id', 'league_id', 'match_id_y', 'team_id', 'team_id_y', 'team_long_name_x', 'team_long_name_y']

try:
    df_teams_matches_save = df_teams_matches.drop(remove_cols, axis='columns', errors='ignore')
    df_teams_matches_save.to_csv(f"data/Mathces_with_full_team_details_{threshold_over_50}.csv")
    pass
except Exception as e:
    print('exception6', e)

print('done')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3155: DtypeWarning: Columns (7,11,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# Index(['Unnamed: 0', 'index', 'match_id', 'team_id', 'shots_on_first_half',
#        'shots_on_second_half', 'goals_first_half', 'T', 'id_x', 'country_id',
#        ...
#        'curr_bets', 'rival_bets', 'curr_team_api_id', 'rival_team_api_id',
#        'curr_shots_1', 'rival_shots_1', 'month', 'team_long_name', 'id_y',
#        'country_name'],
#       dtype='object', length=169) Index(['match_id', 'cards'], dtype='object')
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3155: DtypeWarning: Columns (0,12,17,22) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# done
